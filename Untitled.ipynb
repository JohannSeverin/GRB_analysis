# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.signal import medfilt
# %matplotlib notebook

# %%
def plot_lc(grbname,axes,filt=1):
    names = ['Time','b1','b1er','b2','b2er','b3','b3er','b4','b4er','b5','b5er']
    lc = pd.read_csv("BAT_lc/%s_lc.dat"%grbname,sep = ' ',names=names)
    for band, colour in zip(['b1','b2','b3','b4'],['k','r','g','b']):
        axes.plot(lc.Time,medfilt(lc.loc[:,band],filt),c=colour,alpha=1)
        axes.set_title(grbname)
    return

# %%
fig, ax = plt.subplots(3,sharex=True)
grbs = ['GRB091018','GRB111121A','GRB060313']
for i in range(len(ax)):
    plot_lc(grbs[i],ax[i])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax[0].set_xlim(-4,10)
# Out:
# (-4, 10)

# %%
for i in range(3):
    ax[i].tick_params(axis='y',right=True,left=False,labelright=True,labelleft=False)
ax[1].set_ylabel('counts/sec/det',rotation=-90,labelpad=-385)
ax[2].set_xlabel('Time since BAT-trigger $[s]$')
# Out:
# Text(0.5, 23.52222222222222, 'Time since BAT-trigger $[s]$')

# %%
# fig.savefig('3GRBs_right.svg')

# %%
emb = pd.read_pickle('embedding.dat')
emb.head()
# Out:
#       GRBname     T100          0          1
# 0   GRB041217    7.064   5.843310 -22.812071
# 1  GRB041219C   12.000  -1.500921 -15.841056
# 2   GRB041220    7.020   9.185290 -26.111900
# 3   GRB041223  156.480 -35.118481  11.654624
# 4   GRB041224  226.924 -23.605627  15.216274

# %%
cat = pd.read_pickle('Category_of_GRBs')
cat.head()
# Out:
#                T100   Cat
# GRB name
# GRB190727B   60.444  Long
# GRB190719C  202.404  Long
# GRB190718A  720.000  Long
# GRB190706B   51.584  Long
# GRB190701A   54.976  Long

# %%
cat.loc[emb.GRBname,'Cat'].value_counts()
# Out:
# Long     1145
# Short     109
# Name: Cat, dtype: int64

# %%
len(cat.loc[cat.Cat == 'Discarded'])
# Out:
# 64
